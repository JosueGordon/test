# %%
import os
from pathlib import Path


home = os.getcwd()
print(home)
os.listdir(home)

# %%
import os
from pathlib import Path

home = os.getcwd()
print(home)

# %%
os.listdir(home)

# %%
os.listdir(".")
